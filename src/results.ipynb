# %%
from Algorithm import Algorithm
import numpy as np
import DataUtil

Ks = np.arange(4, 10, 1)
length = 100

for k in Ks:
    total_data_bits = k * 4e3
    D = DataUtil.generate_D_k_distribution(length, k) * total_data_bits
    D = D.numpy()
    H = DataUtil.generate_channel_gains(length, k)
    H = H.numpy()
    print('K =',k,'\n---------------')
    algo = Algorithm(D, H, None, None)
    algo.optimize('new')
    result_df = algo.to_df()
    print(result_df)
# Out:
# K = 4
# ---------------
# start training
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 16
#      14 print('K =',k,'\n---------------')
#      15 algo = Algorithm(D, H, None, None)
# ---> 16 algo.optimize('new')
#      17 result_df = algo.to_df()
#      18 print(result_df)
#
# File ~/Documents/Bachelor-Thesis/src/Algorithm.py:304, in Algorithm.optimize(self, model, max_iters, tol, follower_iters)
#     300 start = time.perf_counter()
#     302 for it in range(max_iters):
#     303     # 1. Leader optimization: update self.b and self.f
# --> 304     self.leader_optimization(model)
#     306     # 2. Follower optimization: update self.lam
#     307     self.follower_optimization(num_iters=follower_iters)
#
# File ~/Documents/Bachelor-Thesis/src/Algorithm.py:177, in Algorithm.leader_optimization(self, model)
#     175     return
#     176 elif model == 'new':
# --> 177     model = self.train_new_model()
#     178     return
#     180 X = self.to_X()
#
# File ~/Documents/Bachelor-Thesis/src/Algorithm.py:109, in Algorithm.train_new_model(self)
#     106 early_stopper = EarlyStopping(patience=5, min_delta=0.1)
#     107 loss_fn = unsupervised_loss
# --> 109 train(model, train_loader, test_loader, optimizer, scheduler, early_stopper, loss_fn, self.device, n_epoch=100)
#     111 return model
#
# File ~/Documents/Bachelor-Thesis/src/TrainingUtil.py:102, in train(model, train_loader, test_loader, optimizer, scheduler, early_stopper, loss_fn, device, n_epoch, path_to_weight)
#     100 print("start training")
#     101 for i in range(n_epoch):
# --> 102     train_loss = train_loop(model, train_loader, optimizer, loss_fn, device)
#     103     test_loss = test_loop(model, test_loader, loss_fn, device)
#     104     loss_list.append(test_loss)
#
# File ~/Documents/Bachelor-Thesis/src/TrainingUtil.py:38, in train_loop(model, data_loader, optimizer, loss_fn, device)
#      35 X = X[0].to(device)
#      36 # 2. Forward Pass
#      37 # The model predicts optimal Bandwidth, Compute, and Compression based on the scenario
# ---> 38 b_pred, f_pred = model(X)  # Model takes |H_k|^2 as input
#      39 # 3. Physics Calculation for Loss
#      40 loss = loss_fn(X, b_pred, f_pred)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Documents/Bachelor-Thesis/src/NNSolver.py:87, in Net.forward(self, x)
#      78 b_k = softmax_with_floor_and_temp(
#      79     logits_b,
#      80     self.B_total,
#      81     min_share=1e-2,
#      82     temp=0.1,
#      83 )
#      85 A = ProcessTime.t_comp(x, b_k, None) + ProcessTime.t_tr(x, b_k, None)
# ---> 87 f_dt_k = allocate_f_from_A(
#      88     A=A,
#      89     D_k=D_k,
#      90     C_DT_total=self.C_DT_total,
#      91 )
#      93 return b_k, f_dt_k
#
# File ~/Documents/Bachelor-Thesis/src/NNSolver.py:110, in allocate_f_from_A(A, D_k, C_DT_total, num_iter)
#     106     f_sum = torch.sum(f_mid, dim=1, keepdim=True)
#     108     too_much_compute = f_sum > C_DT_total
# --> 110     low = torch.where(too_much_compute, mid, low)
#     111     high = torch.where(too_much_compute, high, mid)
#     113 T_star = high
#
# KeyboardInterrupt:
